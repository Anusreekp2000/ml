# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('Salary_Data.csv')
data.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
X = data.drop('Salary', axis=1)
y = data['Salary']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
#modelling Ridge
from sklearn.linear_model import Ridge, Lasso

ridge_model = Ridge(alpha=1.0)
ridge_model.fit(X_train, y_train)
ridge_pred = ridge_model.predict(X_test)

# %%
#modelling Lasso
lasso_model = Lasso(alpha=1.0)
lasso_model.fit(X_train, y_train)
lasso_pred = lasso_model.predict(X_test)

# %%
#prediction
print("Ridge predict: ",ridge_pred)
print("Lasso Predict: ",lasso_pred)
# Out:
# Ridge predict:  [ 40954.63208201 122396.65672228  65017.048453    63166.09334754
#  114992.83630044 107589.0158786 ]
# Lasso Predict:  [ 40749.49519626 122698.83728701  64961.80081398  63099.31576646
#  115248.89709694 107798.95690687]

# %%
#mse
from sklearn. metrics import mean_squared_error
ridge_mse = mean_squared_error(y_test, ridge_pred)
lasso_mse = mean_squared_error(y_test, lasso_pred)
print("Ridge MSE: ", ridge_mse)
print("Lasso MSE: ", lasso_mse)
# Out:
# Ridge MSE:  13445587.269759702
# Lasso MSE:  12824917.186168559

# %%
#Ridge plot
plt.scatter(X_test,y_test,color='red')
plt.plot(X_test,ridge_pred,color ='blue')
plt.title('Salary vs Years of Experience')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %%
#lasso plot
plt.scatter(X_test,y_test,color='red')
plt.plot(X_test,lasso_pred,color ='blue')
plt.title('Salary vs Years of Experience')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()
